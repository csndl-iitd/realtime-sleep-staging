# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install mne
import mne
# !pip install pyEDFlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 40.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 13.2 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/iitjodhpur/sleep-edf-database-expanded-1.0.0/sleep-edf-database-expanded-1.0.0
# Out:
# /content/drive/MyDrive/iitjodhpur/sleep-edf-database-expanded-1.0.0/sleep-edf-database-expanded-1.0.0

# %%
import numpy as np
import mne
edf = mne.io.read_raw_edf('D:\sleep-cassette\SC4001E0-PSG.edf')
header = ','.join(edf.ch_names)
np.savetxt('sleep.csv', edf.get_data().T, delimiter=',', header=header)
# Out:
# Extracting EDF parameters from /content/drive/MyDrive/iitjodhpur/sleep-edf-database-expanded-1.0.0/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4001EC-Hypnogram.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# <ipython-input-25-5c7c6ea592a4>:3: RuntimeWarning: Header information is incorrect for record length. Default record length set to 1.
# It is possible that this file only contains annotations and no signals. In that case, please use mne.read_annotations() to load these annotations.
#   edf = mne.io.read_raw_edf('sleep-cassette/SC4001EC-Hypnogram.edf')
# <ipython-input-25-5c7c6ea592a4>:3: RuntimeWarning: Omitted 153 annotation(s) that were outside data range.
#   edf = mne.io.read_raw_edf('sleep-cassette/SC4001EC-Hypnogram.edf')
# <ipython-input-25-5c7c6ea592a4>:3: RuntimeWarning: Limited 1 annotation(s) that were expanding outside the data range.
#   edf = mne.io.read_raw_edf('sleep-cassette/SC4001EC-Hypnogram.edf')
# ...

# %%
raw_data = data.get_data()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-f0148096da87> in <cell line: 1>()
# ----> 1 raw_data = data.get_data()
#
# NameError: name 'data' is not defined

# %%
import pandas as pd
sleep_data = pd.read_csv('sleep.csv')
sleep_data
# Out:
#          # EEG Fpz-Cz     EEG Pz-Oz  EOG horizontal  Resp oro-nasal  \
# 0            0.000005 -2.467399e-06        0.000017     -482.000000
# 1           -0.000003  1.467399e-06        0.000016     -479.674851
# 2            0.000001 -4.098901e-06        0.000010     -477.059581
# 3           -0.000002 -2.659341e-06        0.000002     -474.153663
# 4           -0.000005 -7.399267e-07        0.000008     -470.956747
# ...               ...           ...             ...             ...
# 7949995      0.000011 -6.882051e-06        0.000082     -489.304581
# 7949996      0.000004 -8.609524e-06        0.000062     -488.416044
# 7949997      0.000005 -3.043223e-06        0.000070     -487.242620
# 7949998     -0.000005 -3.715018e-06        0.000081     -485.782923
# 7949999      0.000007  1.755311e-06        0.000102     -484.035732
#
#          EMG submental  Temp rectal  Event marker
# 0             0.000004    37.206452    920.000000
# ...

# %%
import pandas as pd
sleep_data = pd.read_csv('sleep2.csv')
sleep2_data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-4454c7a77854> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 sleep_data = pd.read_csv('sleep2.csv')
#       3 sleep2_data
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pyedflib
import numpy as np
import os

file_name = ('sleep-cassette/SC4001E0-PSG.edf')
f = pyedflib.EdfReader(file_name)
annotations = f.readAnnotations()
print(annotations)
# Out:
# (array([], dtype=float64), array([], dtype=float64), array([], dtype=float64))

# %%
import numpy as np
import matplotlib.pyplot as plt

import mne
from mne.datasets.sleep_physionet.age import fetch_data
# from mne.time_frequency import

# %%
ALICE, BOB = 0, 1

[alice_files, bob_files] = fetch_data(subjects=[ALICE, BOB], recording=[1])

mapping = {'EOG horizontal': 'eog',
           'Resp oro-nasal': 'misc',
           'EMG submental': 'misc',
           'Temp rectal': 'misc',
           'Event marker': 'misc'}
# Out:
# Using default location ~/mne_data for PHYSIONET_SLEEP...
# Creating ~/mne_data
# ...
# 100%|█████████████████████████████████████| 48.3M/48.3M [00:00<00:00, 24.9GB/s]
# ...
# 100%|█████████████████████████████████████| 4.62k/4.62k [00:00<00:00, 1.64MB/s]
# ...
# 100%|█████████████████████████████████████| 51.1M/51.1M [00:00<00:00, 18.3GB/s]
# ...
# 100%|█████████████████████████████████████| 3.90k/3.90k [00:00<00:00, 1.48MB/s]
# Download complete in 02m56s (94.8 MB)

# %%
raw_train = mne.io.read_raw_edf(alice_files[0])
annot_train = mne.read_annotations(alice_files[1])

raw_train.set_annotations(annot_train, emit_warning=False)
raw_train.set_channel_types(mapping)

# plot some data
raw_train.plot(duration=60, scalings='auto')
# Out:
# Extracting EDF parameters from /root/mne_data/physionet-sleep-data/SC4001E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# <ipython-input-19-ebf79729a6f2>:1: RuntimeWarning: Channels contain different highpass filters. Highest filter setting will be stored.
#   raw_train = mne.io.read_raw_edf(alice_files[0])
# <ipython-input-19-ebf79729a6f2>:1: RuntimeWarning: Channels contain different lowpass filters. Lowest filter setting will be stored.
#   raw_train = mne.io.read_raw_edf(alice_files[0])
# <ipython-input-19-ebf79729a6f2>:1: RuntimeWarning: Highpass cutoff frequency 16.0 is greater than lowpass cutoff frequency 0.7, setting values to 0 and Nyquist.
#   raw_train = mne.io.read_raw_edf(alice_files[0])
# <ipython-input-19-ebf79729a6f2>:5: RuntimeWarning: The unit for channel(s) EMG submental, Event marker, Resp oro-nasal, Temp rectal has changed from V to NA.
#   raw_train.set_channel_types(mapping)
# ...
